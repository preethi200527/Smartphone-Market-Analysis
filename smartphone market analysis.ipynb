# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-98fee7be-9918-4646-a150-b301a687aa9d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98fee7be-9918-4646-a150-b301a687aa9d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/smartphones.csv')

df.head()
# Out:
#   smartphone_brand                            model  price_inr  rating_score  \
# 0        blackzone         BlackZone S25 Ultra Maxx       8999            63
# 1           ringme                  Ringme Bold P70       5800            44
# 2             lava  Lava Shark 5G (4GB RAM + 128GB)       8998            60
# 3             vivo   Vivo Y19s 5G (4GB RAM + 128GB)      11999            69
# 4             vivo    Vivo Y19s 5G (4GB RAM + 64GB)      10999            68
#
#             processor_name processor_brand  core_count  clock_speed_ghz  \
# 0          unisoc sc9863a1          unisoc           8              1.6
# 1           mediatek helio        mediatek           2              1.3
# 2              unisoc t765          unisoc           8              2.3
# 3  mediatek dimensity 6300        mediatek           8              2.4
# 4  mediatek dimensity 6300        mediatek           8              2.4
#
# ...

# %%
df.shape
# Out:
# (758, 27)

# %%
df.columns
# Out:
# Index(['smartphone_brand', 'model', 'price_inr', 'rating_score',
#        'processor_name', 'processor_brand', 'core_count', 'clock_speed_ghz',
#        'ram_gb', 'storage_gb', 'has_5g', 'has_nfc', 'has_ir_blaster',
#        'display_inches', 'res_width_px', 'res_height_px', 'refresh_rate_hz',
#        'battery_mah', 'fast_charging', 'charging_watt', 'rear_camera_count',
#        'front_camera_count', 'rear_camera_main_mp', 'front_camera_main_mp',
#        'os_name', 'memory_card_supported', 'memory_card_type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   smartphone_brand       758 non-null    object
#  1   model                  758 non-null    object
#  2   price_inr              758 non-null    int64
#  3   rating_score           758 non-null    int64
#  4   processor_name         758 non-null    object
#  5   processor_brand        758 non-null    object
#  6   core_count             758 non-null    int64
#  7   clock_speed_ghz        758 non-null    float64
#  8   ram_gb                 758 non-null    int64
#  9   storage_gb             758 non-null    int64
#  10  has_5g                 758 non-null    bool
#  11  has_nfc                758 non-null    bool
#  12  has_ir_blaster         758 non-null    bool
#  13  display_inches         758 non-null    float64
#  14  res_width_px           758 non-null    int64
# ...

# %%
df.isnull().sum()

[1]
28s
from google.colab import files

uploaded = files.upload()


[2]
0s
import pandas as pd

df = pd.read_csv('/content/smartphones.csv')

df.head()


[3]
0s
df.shape

(758, 27)

[4]
0s
df.columns
Index(['smartphone_brand', 'model', 'price_inr', 'rating_score',
       'processor_name', 'processor_brand', 'core_count', 'clock_speed_ghz',
       'ram_gb', 'storage_gb', 'has_5g', 'has_nfc', 'has_ir_blaster',
       'display_inches', 'res_width_px', 'res_height_px', 'refresh_rate_hz',
       'battery_mah', 'fast_charging', 'charging_watt', 'rear_camera_count',
       'front_camera_count', 'rear_camera_main_mp', 'front_camera_main_mp',
       'os_name', 'memory_card_supported', 'memory_card_type'],
      dtype='object')

[5]
0s
df.info()
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 758 entries, 0 to 757
Data columns (total 27 columns):
 #   Column                 Non-Null Count  Dtype
---  ------                 --------------  -----
 0   smartphone_brand       758 non-null    object
 1   model                  758 non-null    object
 2   price_inr              758 non-null    int64
 3   rating_score           758 non-null    int64
 4   processor_name         758 non-null    object
 5   processor_brand        758 non-null    object
 6   core_count             758 non-null    int64
 7   clock_speed_ghz        758 non-null    float64
 8   ram_gb                 758 non-null    int64
 9   storage_gb             758 non-null    int64
 10  has_5g                 758 non-null    bool
 11  has_nfc                758 non-null    bool
 12  has_ir_blaster         758 non-null    bool
 13  display_inches         758 non-null    float64
 14  res_width_px           758 non-null    int64
 15  res_height_px          758 non-null    int64
 16  refresh_rate_hz        758 non-null    int64
 17  battery_mah            758 non-null    int64
 18  fast_charging          758 non-null    bool
 19  charging_watt          758 non-null    float64
 20  rear_camera_count      758 non-null    int64
 21  front_camera_count     758 non-null    int64
 22  rear_camera_main_mp    758 non-null    float64
 23  front_camera_main_mp   753 non-null    float64
 24  os_name                758 non-null    object
 25  memory_card_supported  551 non-null    object
 26  memory_card_type       551 non-null    object
dtypes: bool(4), float64(5), int64(11), object(7)
memory usage: 139.3+ KB

[6]
0s
df.isnull().sum()

Colab paid products
-
Cancel contracts here
$0
# Out:
# smartphone_brand           0
# model                      0
# price_inr                  0
# rating_score               0
# processor_name             0
# processor_brand            0
# core_count                 0
# clock_speed_ghz            0
# ram_gb                     0
# storage_gb                 0
# has_5g                     0
# has_nfc                    0
# has_ir_blaster             0
# display_inches             0
# res_width_px               0
# res_height_px              0
# refresh_rate_hz            0
# battery_mah                0
# fast_charging              0
# charging_watt              0
# rear_camera_count          0
# front_camera_count         0
# rear_camera_main_mp        0
# front_camera_main_mp       5
# os_name                    0
# memory_card_supported    207
# memory_card_type         207
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(419)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#            price_inr  rating_score  core_count  clock_speed_ghz      ram_gb  \
# count     758.000000    758.000000  758.000000       758.000000  758.000000
# mean    29424.088391     78.587071    7.906332         2.597889    7.990765
# std     32989.687389      8.372894    0.701338         0.596162    3.134361
# min      4040.000000     37.000000    1.000000         1.000000    2.000000
# 25%     11857.250000     74.000000    8.000000         2.300000    6.000000
# 50%     18999.000000     80.000000    8.000000         2.400000    8.000000
# 75%     29990.000000     84.000000    8.000000         2.800000    8.000000
# max    229900.000000     97.000000   10.000000         4.470000   24.000000
#
#         storage_gb  display_inches  res_width_px  res_height_px  \
# count   758.000000      758.000000    758.000000     758.000000
# mean    220.496042        6.697810   1043.919525    2234.897098
# std     168.366358        0.285648    260.683929     494.157749
# ...

# %%
df['front_camera_main_mp'] = df['front_camera_main_mp'].fillna(
    df['front_camera_main_mp'].median()
)

# %%
df['memory_card_supported'] = df['memory_card_supported'].fillna('Not Specified')

df['memory_card_type'] = df['memory_card_type'].fillna('Not Specified')

# %%
df.isnull().sum()
# Out:
# smartphone_brand         0
# model                    0
# price_inr                0
# rating_score             0
# processor_name           0
# processor_brand          0
# core_count               0
# clock_speed_ghz          0
# ram_gb                   0
# storage_gb               0
# has_5g                   0
# has_nfc                  0
# has_ir_blaster           0
# display_inches           0
# res_width_px             0
# res_height_px            0
# refresh_rate_hz          0
# battery_mah              0
# fast_charging            0
# charging_watt            0
# rear_camera_count        0
# front_camera_count       0
# rear_camera_main_mp      0
# front_camera_main_mp     0
# os_name                  0
# memory_card_supported    0
# memory_card_type         0
# dtype: int64

# %%
brand_count = df['smartphone_brand'].value_counts()

brand_count
# Out:
# smartphone_brand
# realme       134
# samsung      104
# vivo          94
# oppo          67
# xiaomi        41
# motorola      40
# lava          40
# poco          31
# tecno         31
# iqoo          29
# infinix       28
# apple         28
# oneplus       20
# nothing       14
# itel          14
# google        11
# hmd            5
# alcatel        5
# ai+            4
# cmf            4
# peace          4
# acer           3
# honor          3
# blackzone      2
# ulefone        1
# ringme         1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

brand_count.plot(kind='bar', figsize=(10,5))

plt.title('Number of Smartphones by Brand')
plt.xlabel('Smartphone Brand')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=45)
plt.show()

# %%
df.isnull().sum()
# Out:
# smartphone_brand         0
# model                    0
# price_inr                0
# rating_score             0
# processor_name           0
# processor_brand          0
# core_count               0
# clock_speed_ghz          0
# ram_gb                   0
# storage_gb               0
# has_5g                   0
# has_nfc                  0
# has_ir_blaster           0
# display_inches           0
# res_width_px             0
# res_height_px            0
# refresh_rate_hz          0
# battery_mah              0
# fast_charging            0
# charging_watt            0
# rear_camera_count        0
# front_camera_count       0
# rear_camera_main_mp      0
# front_camera_main_mp     0
# os_name                  0
# memory_card_supported    0
# memory_card_type         0
# dtype: int64

# %%
brand_count = df['smartphone_brand'].value_counts()

brand_count
# Out:
# smartphone_brand
# realme       134
# samsung      104
# vivo          94
# oppo          67
# xiaomi        41
# motorola      40
# lava          40
# poco          31
# tecno         31
# iqoo          29
# infinix       28
# apple         28
# oneplus       20
# nothing       14
# itel          14
# google        11
# hmd            5
# alcatel        5
# ai+            4
# cmf            4
# peace          4
# acer           3
# honor          3
# blackzone      2
# ulefone        1
# ringme         1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

brand_count.plot(kind='bar', figsize=(10,5))

plt.title('Number of Smartphones by Brand')
plt.xlabel('Smartphone Brand')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=45)
plt.show()

# %%
avg_price = df.groupby('smartphone_brand')['price_inr'].mean().sort_values(ascending=False)

avg_price
# Out:
# smartphone_brand
# apple        124709.821429
# google        92040.272727
# ulefone       86500.000000
# oneplus       48019.050000
# samsung       43086.048077
# honor         33662.333333
# nothing       28506.285714
# vivo          28336.361702
# iqoo          25330.655172
# oppo          25112.253731
# motorola      23944.425000
# realme        19798.835821
# tecno         18914.225806
# infinix       17902.321429
# cmf           17187.000000
# xiaomi        16149.829268
# hmd           15999.000000
# poco          15699.806452
# alcatel       13599.000000
# lava          10335.175000
# acer          10189.000000
# blackzone      8249.500000
# ai+            7999.000000
# itel           7818.500000
# ringme         5800.000000
# peace          4694.500000
# Name: price_inr, dtype: float64

# %%
avg_price.plot(kind='bar', figsize=(10,5))

plt.title('Average Smartphone Price by Brand')
plt.xlabel('Smartphone Brand')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=45)
plt.show()

# %%
avg_price.head(5)
# Out:
# smartphone_brand
# apple      124709.821429
# google      92040.272727
# ulefone     86500.000000
# oneplus     48019.050000
# samsung     43086.048077
# Name: price_inr, dtype: float64

# %%
ram_price = df.groupby('ram_gb')['price_inr'].mean().sort_index()

ram_price
# Out:
# ram_gb
# 2      5498.000000
# 3      5921.058824
# 4      9328.132353
# 6     14581.860000
# 8     28570.847561
# 12    51442.136054
# 16    87616.428571
# 24    83999.000000
# Name: price_inr, dtype: float64

# %%
ram_price.plot(kind='bar', figsize=(8,5))

plt.title('Average Smartphone Price by RAM')
plt.xlabel('RAM (GB)')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
ram_count = df['ram_gb'].value_counts().sort_index()

ram_count
# Out:
# ram_gb
# 2       1
# 3      17
# 4     136
# 6     100
# 8     328
# 12    147
# 16     28
# 24      1
# Name: count, dtype: int64

# %%
ram_count.plot(kind='bar', figsize=(8,5))

plt.title('Number of Smartphones by RAM')
plt.xlabel('RAM (GB)')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
fiveg_count = df['has_5g'].value_counts()

fiveg_count
# Out:
# has_5g
# True     657
# False    101
# Name: count, dtype: int64

# %%
fiveg_count.plot(kind='bar', figsize=(7,5))

plt.title('5G vs Non-5G Smartphones')
plt.xlabel('5G Support')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
fiveg_price = df.groupby('has_5g')['price_inr'].mean()

fiveg_price
# Out:
# has_5g
# False     7942.851485
# True     32726.378995
# Name: price_inr, dtype: float64

# %%
fiveg_price.plot(kind='bar', figsize=(7,5))

plt.title('Average Price: 5G vs Non-5G Smartphones')
plt.xlabel('5G Support')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
df['battery_category'] = pd.cut(
    df['battery_mah'],
    bins=[0, 4000, 5000, 6000, 10000],
    labels=['Below 4000', '4000-5000', '5000-6000', 'Above 6000']
)

# %%
battery_count = df['battery_category'].value_counts().sort_index()

battery_count
# Out:
# battery_category
# Below 4000     36
# 4000-5000     368
# 5000-6000     252
# Above 6000    101
# Name: count, dtype: int64

# %%
battery_count.plot(kind='bar', figsize=(8,5))

plt.title('Number of Smartphones by Battery Capacity')
plt.xlabel('Battery Capacity (mAh)')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
battery_price = df.groupby(
    'battery_category',
    observed=True
)['price_inr'].mean()

battery_price
# Out:
# battery_category
# Below 4000    83245.777778
# 4000-5000     26648.486413
# 5000-6000     26743.460317
# Above 6000    26476.396040
# Name: price_inr, dtype: float64

# %%
battery_price.plot(kind='bar', figsize=(8,5))

plt.title('Average Smartphone Price by Battery Category')
plt.xlabel('Battery Capacity')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
storage_price = df.groupby('storage_gb')['price_inr'].mean().sort_index()

storage_price
# Out:
# storage_gb
# 32        4855.200000
# 64        7855.718310
# 128      15586.972308
# 256      33978.645522
# 512      72422.948718
# 1024    167049.400000
# 2048    229900.000000
# Name: price_inr, dtype: float64

# %%
storage_price.plot(kind='bar', figsize=(8,5))

plt.title('Average Smartphone Price by Storage')
plt.xlabel('Storage (GB)')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
storage_count = df['storage_gb'].value_counts().sort_index()

storage_count
# Out:
# storage_gb
# 32        5
# 64       71
# 128     325
# 256     268
# 512      78
# 1024     10
# 2048      1
# Name: count, dtype: int64

# %%
storage_count.plot(kind='bar', figsize=(8,5))

plt.title('Number of Smartphones by Storage')
plt.xlabel('Storage (GB)')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['rating_score'], df['price_inr'])

plt.title('Rating vs Smartphone Price')
plt.xlabel('Rating Score')
plt.ylabel('Price (INR)')
plt.show()

# %%
processor_count = df['processor_brand'].value_counts()

processor_count
# Out:
# processor_brand
# mediatek      388
# snapdragon    219
# unisoc         68
# exynos         44
# apple          28
# tensor         11
# Name: count, dtype: int64

# %%
processor_count.plot(kind='bar', figsize=(8,5))

plt.title('Number of Smartphones by Processor Brand')
plt.xlabel('Processor Brand')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=45)
plt.show()

# %%
processor_price = df.groupby('processor_brand')['price_inr'].mean().sort_values(ascending=False)

processor_price
# Out:
# processor_brand
# apple         124709.821429
# tensor         92040.272727
# snapdragon     36698.479452
# exynos         35357.636364
# mediatek       19818.340206
# unisoc          7601.794118
# Name: price_inr, dtype: float64

# %%
processor_price.plot(kind='bar', figsize=(8,5))

plt.title('Average Smartphone Price by Processor Brand')
plt.xlabel('Processor Brand')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=45)
plt.show()

# %%
os_count = df['os_name'].value_counts()

os_count
# Out:
# os_name
# android    730
# ios         28
# Name: count, dtype: int64

# %%
os_count.plot(kind='bar', figsize=(7,5))

plt.title('Number of Smartphones by Operating System')
plt.xlabel('Operating System')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['rear_camera_main_mp'], df['price_inr'])

plt.title('Rear Camera MP vs Smartphone Price')
plt.xlabel('Rear Camera (MP)')
plt.ylabel('Price (INR)')
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['front_camera_main_mp'], df['price_inr'])

plt.title('Front Camera MP vs Smartphone Price')
plt.xlabel('Front Camera (MP)')
plt.ylabel('Price (INR)')
plt.show()

# %%
camera_price = df.groupby('rear_camera_main_mp')['price_inr'].mean().sort_index()

camera_price
# Out:
# rear_camera_main_mp
# 8.0        7218.045455
# 12.0      53749.000000
# 13.0       8215.947368
# 16.0       7994.500000
# 32.0      10431.560000
# 40.0       7500.000000
# 48.0      99402.625000
# 50.0      26366.380150
# 64.0      29353.934783
# 100.0     27999.000000
# 108.0     17875.454545
# 200.0    101197.000000
# Name: price_inr, dtype: float64

# %%
refresh_count = df['refresh_rate_hz'].value_counts().sort_index()

refresh_count
# Out:
# refresh_rate_hz
# 60      31
# 90     136
# 120    529
# 144     60
# 165      2
# Name: count, dtype: int64

# %%
refresh_count.plot(kind='bar', figsize=(8,5))

plt.title('Number of Smartphones by Refresh Rate')
plt.xlabel('Refresh Rate (Hz)')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
refresh_price = df.groupby('refresh_rate_hz')['price_inr'].mean().sort_index()

refresh_price
# Out:
# refresh_rate_hz
# 60     29856.677419
# 90     10605.970588
# 120    34523.837429
# 144    25454.200000
# 165    72564.000000
# Name: price_inr, dtype: float64

# %%
refresh_price.plot(kind='bar', figsize=(8,5))

plt.title('Average Smartphone Price by Refresh Rate')
plt.xlabel('Refresh Rate (Hz)')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['display_inches'], df['price_inr'])

plt.title('Display Size vs Smartphone Price')
plt.xlabel('Display Size (inches)')
plt.ylabel('Price (INR)')
plt.show()

# %%
charging_count = df['fast_charging'].value_counts()

charging_count
# Out:
# fast_charging
# True     746
# False     12
# Name: count, dtype: int64

# %%
charging_count.plot(kind='bar', figsize=(7,5))

plt.title('Fast Charging Support')
plt.xlabel('Fast Charging')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
charging_price = df.groupby('fast_charging')['price_inr'].mean()

charging_price
# Out:
# fast_charging
# False     8079.250000
# True     29767.436997
# Name: price_inr, dtype: float64

# %%
charging_price.plot(kind='bar', figsize=(7,5))

plt.title('Average Price: Fast Charging vs Non-Fast Charging')
plt.xlabel('Fast Charging')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['charging_watt'], df['price_inr'])

plt.title('Charging Watt vs Smartphone Price')
plt.xlabel('Charging Power (Watt)')
plt.ylabel('Price (INR)')
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')

price_correlation = numeric_df.corr()['price_inr'].sort_values(ascending=False)

price_correlation
# Out:
# price_inr               1.000000
# clock_speed_ghz         0.784438
# storage_gb              0.754398
# res_width_px            0.589910
# ram_gb                  0.548027
# rating_score            0.541073
# res_height_px           0.443512
# front_camera_count      0.417493
# rear_camera_count       0.358635
# rear_camera_main_mp     0.272761
# display_inches          0.236955
# front_camera_main_mp    0.172568
# refresh_rate_hz         0.164367
# charging_watt           0.132872
# battery_mah            -0.154588
# core_count             -0.210701
# Name: price_inr, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(12,8))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    fmt='.2f',
    cmap='coolwarm'
)

plt.title('Correlation Heatmap of Smartphone Features')
plt.show()

# %%
price_correlation
# Out:
# price_inr               1.000000
# clock_speed_ghz         0.784438
# storage_gb              0.754398
# res_width_px            0.589910
# ram_gb                  0.548027
# rating_score            0.541073
# res_height_px           0.443512
# front_camera_count      0.417493
# rear_camera_count       0.358635
# rear_camera_main_mp     0.272761
# display_inches          0.236955
# front_camera_main_mp    0.172568
# refresh_rate_hz         0.164367
# charging_watt           0.132872
# battery_mah            -0.154588
# core_count             -0.210701
# Name: price_inr, dtype: float64

# %%
top_10_expensive = df[
    ['smartphone_brand', 'model', 'price_inr', 'ram_gb', 'storage_gb']
].sort_values('price_inr', ascending=False).head(10)

top_10_expensive
# Out:
#     smartphone_brand                                       model  price_inr  \
# 45             apple               Apple iPhone 17 Pro Max (2TB)     229900
# 116          samsung    Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)     216999
# 516          samsung    Samsung Galaxy Z Fold 6 (12GB RAM + 1TB)     200999
# 46             apple               Apple iPhone 17 Pro Max (1TB)     189900
# 117          samsung  Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)     186999
# 517          samsung  Samsung Galaxy Z Fold 6 (12GB RAM + 512GB)     176999
# 511          samsung                     Samsung Galaxy Z Fold 7     174999
# 43             apple                   Apple iPhone 17 Pro (1TB)     174900
# 366           google                    Google Pixel 10 Pro Fold     172999
# 47             apple             Apple iPhone 17 Pro Max (512GB)     169900
#
#      ram_gb  storage_gb
# 45       12        2048
# 116      16        1024
# 516      12        1024
# 46       12        1024
# ...

# %%
top_rated = df[
    ['smartphone_brand', 'model', 'rating_score', 'price_inr', 'ram_gb', 'storage_gb']
].sort_values('rating_score', ascending=False).head(10)

top_rated
# Out:
#     smartphone_brand                                       model  \
# 116          samsung    Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)
# 674             vivo                           Vivo X Fold 3 Pro
# 9            ulefone                     Ulefone Armor 29 Pro 5G
# 683            tecno                      Tecno Phantom V Fold 2
# 511          samsung                     Samsung Galaxy Z Fold 7
# 117          samsung  Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)
# 537             vivo                            Vivo X200 Pro 5G
# 457          oneplus                OnePlus Open 5G Apex Edition
# 294          samsung   Samsung Galaxy S25 Ultra (12GB RAM + 1TB)
# 378             vivo                            Vivo X Fold 5 5G
#
#      rating_score  price_inr  ram_gb  storage_gb
# 116            97     216999      16        1024
# 674            96     159999      16         512
# 9              96      86500      16         512
# 683            95      89999      12         512
# ...

# %%
rating_count = df['rating_score'].value_counts().sort_index()

rating_count
# Out:
# rating_score
# 37     2
# 38     1
# 40     1
# 44     1
# 48     1
# 51     1
# 53     1
# 55     3
# 56     3
# 57     6
# 58     3
# 59     1
# 60     1
# 61     6
# 62     4
# 63     4
# 64     8
# 65     2
# 66     2
# 67    11
# 68    17
# 69    16
# 70    11
# 71    21
# 72    15
# 73    14
# 74    50
# 75    23
# 76    25
# 77    25
# 78    33
# 79    43
# 80    46
# 81    43
# 82    53
# 83    56
# 84    44
# 85    29
# 86    28
# 87    30
# 88    14
# 89    18
# 90    11
# 91    15
# 92     2
# 93     4
# 94     3
# 95     4
# 96     2
# 97     1
# Name: count, dtype: int64

# %%
rating_count.plot(kind='bar', figsize=(8,5))

plt.title('Distribution of Smartphone Ratings')
plt.xlabel('Rating Score')
plt.ylabel('Number of Smartphones')
plt.xticks(rotation=0)
plt.show()

# %%
brand_rating = df.groupby('smartphone_brand')['rating_score'].mean().sort_values(ascending=False)

brand_rating
# Out:
# smartphone_brand
# ulefone      96.000000
# oneplus      86.500000
# nothing      85.071429
# honor        84.000000
# apple        83.535714
# google       83.454545
# samsung      81.673077
# motorola     81.650000
# cmf          81.250000
# iqoo         80.517241
# alcatel      79.400000
# vivo         79.361702
# infinix      79.250000
# realme       78.664179
# oppo         78.462687
# poco         77.645161
# hmd          77.200000
# xiaomi       76.536585
# tecno        75.870968
# acer         74.333333
# lava         69.800000
# ai+          68.500000
# blackzone    62.500000
# itel         61.142857
# ringme       44.000000
# peace        38.000000
# Name: rating_score, dtype: float64

# %%
brand_rating.plot(kind='bar', figsize=(10,5))

plt.title('Average Rating by Smartphone Brand')
plt.xlabel('Smartphone Brand')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
ram_storage_price = df.groupby(
    ['ram_gb', 'storage_gb']
)['price_inr'].mean().reset_index()

ram_storage_price
# Out:
#     ram_gb  storage_gb      price_inr
# 0        2          32    5498.000000
# 1        3          32    4694.500000
# 2        3          64    6298.461538
# 3        4          64    8204.758621
# 4        4         128   10163.461538
# 5        6         128   12807.185567
# 6        6         256   70945.000000
# 7        6         512   73999.000000
# 8        8         128   19877.315436
# 9        8         256   28371.487805
# 10       8         512  105741.166667
# 11       8        1024  162566.666667
# 12      12         128   68999.000000
# 13      12         256   38217.568421
# 14      12         512   63057.130435
# 15      12        1024  182949.500000
# 16      12        2048  229900.000000
# 17      16         256   97256.285714
# 18      16         512   73972.052632
# 19      16        1024  183498.500000
# 20      24        1024   83999.000000

# %%
ram_storage_price.sort_values(
    'price_inr',
    ascending=False
).head(10)
# Out:
#     ram_gb  storage_gb      price_inr
# 16      12        2048  229900.000000
# 19      16        1024  183498.500000
# 15      12        1024  182949.500000
# 11       8        1024  162566.666667
# 10       8         512  105741.166667
# 17      16         256   97256.285714
# 20      24        1024   83999.000000
# 7        6         512   73999.000000
# 18      16         512   73972.052632
# 6        6         256   70945.000000

# %%
plt.figure(figsize=(9,6))

plt.scatter(
    df['ram_gb'],
    df['storage_gb'],
    s=df['price_inr'] / 100
)

plt.title('RAM vs Storage with Price')
plt.xlabel('RAM (GB)')
plt.ylabel('Storage (GB)')
plt.show()

# %%
features = ['ram_gb', 'storage_gb', 'battery_mah',
            'refresh_rate_hz', 'rear_camera_main_mp',
            'charging_watt']

feature_correlation = df[features + ['price_inr']].corr()['price_inr']

feature_correlation.sort_values(ascending=False)
# Out:
# price_inr              1.000000
# storage_gb             0.754398
# ram_gb                 0.548027
# rear_camera_main_mp    0.272761
# refresh_rate_hz        0.164367
# charging_watt          0.132872
# battery_mah           -0.154588
# Name: price_inr, dtype: float64

# %%
print("Total Smartphones:", len(df))
print("Total Brands:", df['smartphone_brand'].nunique())
print("Average Price:", df['price_inr'].mean())
print("Minimum Price:", df['price_inr'].min())
print("Maximum Price:", df['price_inr'].max())
print("Average Rating:", df['rating_score'].mean())
# Out:
# Total Smartphones: 758
# Total Brands: 26
# Average Price: 29424.088390501318
# Minimum Price: 4040
# Maximum Price: 229900
# Average Rating: 78.58707124010554

# %%
print("Most Common Brand:")
print(df['smartphone_brand'].value_counts().idxmax())
# Out:
# Most Common Brand:
# realme

# %%
print("Most Common RAM:")
print(df['ram_gb'].mode()[0], "GB")
# Out:
# Most Common RAM:
# 8 GB

# %%
print("Most Common Storage:")
print(df['storage_gb'].mode()[0], "GB")
# Out:
# Most Common Storage:
# 128 GB

# %%
fiveg_percentage = df['has_5g'].mean() * 100

print("5G Smartphones:", round(fiveg_percentage, 2), "%")
# Out:
# 5G Smartphones: 86.68 %

# %%
fast_charge_percentage = df['fast_charging'].mean() * 100

print("Fast Charging Smartphones:", round(fast_charge_percentage, 2), "%")
# Out:
# Fast Charging Smartphones: 98.42 %

# %%
summary = {
    'Total Smartphones': len(df),
    'Total Brands': df['smartphone_brand'].nunique(),
    'Average Price': round(df['price_inr'].mean()),
    'Average Rating': round(df['rating_score'].mean(), 2),
    'Average RAM': round(df['ram_gb'].mean(), 2),
    'Average Battery': round(df['battery_mah'].mean())
}

summary
# Out:
# {'Total Smartphones': 758,
#  'Total Brands': 26,
#  'Average Price': 29424,
#  'Average Rating': np.float64(78.59),
#  'Average RAM': np.float64(7.99),
#  'Average Battery': 5374}

# %%
plt.figure(figsize=(9,5))

plt.hist(df['price_inr'], bins=20)

plt.title('Smartphone Price Distribution')
plt.xlabel('Price (INR)')
plt.ylabel('Number of Smartphones')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['rating_score'], bins=10)

plt.title('Smartphone Rating Distribution')
plt.xlabel('Rating Score')
plt.ylabel('Number of Smartphones')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['battery_mah'], bins=15)

plt.title('Battery Capacity Distribution')
plt.xlabel('Battery Capacity (mAh)')
plt.ylabel('Number of Smartphones')

plt.show()

# %%
df.head(10)
# Out:
#   smartphone_brand                                    model  price_inr  \
# 0        blackzone                 BlackZone S25 Ultra Maxx       8999
# 1           ringme                          Ringme Bold P70       5800
# 2             lava          Lava Shark 5G (4GB RAM + 128GB)       8998
# 3             vivo           Vivo Y19s 5G (4GB RAM + 128GB)      11999
# 4             vivo            Vivo Y19s 5G (4GB RAM + 64GB)      10999
# 5             vivo                             Vivo Y19s 5G      13499
# 6          nothing  Nothing Phone 3a Lite (8GB RAM + 256GB)      20999
# 7         motorola               Motorola Moto G67 Power 5G      15999
# 8            peace                           Peace Honor 30       5599
# 9          ulefone                  Ulefone Armor 29 Pro 5G      86500
#
#    rating_score               processor_name processor_brand  core_count  \
# 0            63              unisoc sc9863a1          unisoc           8
# ...

# %%
print("===== FINAL PROJECT INSIGHTS =====")

print("\n1. Total Smartphones:", len(df))

print("2. Total Brands:", df['smartphone_brand'].nunique())

print("3. Average Price: ₹", round(df['price_inr'].mean()))

print("4. Average Rating:", round(df['rating_score'].mean(), 2))

print("5. Most Common Brand:",
      df['smartphone_brand'].value_counts().idxmax())

print("6. Most Common RAM:",
      df['ram_gb'].mode()[0], "GB")

print("7. Most Common Storage:",
      df['storage_gb'].mode()[0], "GB")

print("8. 5G Smartphone Percentage:",
      round(df['has_5g'].mean() * 100, 2), "%")

print("9. Fast Charging Percentage:",
      round(df['fast_charging'].mean() * 100, 2), "%")
# Out:
# ===== FINAL PROJECT INSIGHTS =====
#
# 1. Total Smartphones: 758
# 2. Total Brands: 26
# 3. Average Price: ₹ 29424
# 4. Average Rating: 78.59
# 5. Most Common Brand: realme
# 6. Most Common RAM: 8 GB
# 7. Most Common Storage: 128 GB
# 8. 5G Smartphone Percentage: 86.68 %
# 9. Fast Charging Percentage: 98.42 %

# %%
df.to_csv('cleaned_smartphones.csv', index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
from google.colab import files

files.download('cleaned_smartphones.csv')
